# %% [markdown]
# # Analysis - 2 Using Chi-Square Test

# %%
# Importing libraries

import pandas as pd
from scipy.stats import chi2_contingency

# %%
# Read starbbucks data

Starbucks_Data = pd.read_csv('Starbucks satisfactory survey encode cleaned.csv', header=0)
Starbucks_Data
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 2      3       0    1       2       0        2       0          1         2
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 108  118       0    3       1       1        2       0          2         1
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
# ...

# %%
# Defining the table
data_crosstab = pd.crosstab(Starbucks_Data['serviceRate'], Starbucks_Data['wifiRate'],margins = False)
print(data_crosstab)

data = data_crosstab.values.tolist()
print(data)
print(type(data))
stat, p, dof, expected = chi2_contingency(data)

# Interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# wifiRate     1  2   3   4  5
# serviceRate
# 2            2  2   0   0  0
# 3            2  7  22   5  0
# 4            2  4  18  24  2
# 5            0  0   7   8  8
# [[2, 2, 0, 0, 0], [2, 7, 22, 5, 0], [2, 4, 18, 24, 2], [0, 0, 7, 8, 8]]
# <class 'list'>
# p value is 4.3283758926926855e-09
# Dependent (reject H0)

# %%
# Defining the table
data_crosstab = pd.crosstab(Starbucks_Data['serviceRate'], Starbucks_Data['ambianceRate'],margins = False)
print(data_crosstab)

data = data_crosstab.values.tolist()
print(data)
print(type(data))
stat, p, dof, expected = chi2_contingency(data)

# Interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# ambianceRate  1  2   3   4   5
# serviceRate
# 2             0  2   2   0   0
# 3             1  2  16  16   1
# 4             0  1  11  27  11
# 5             0  0   2   7  14
# [[0, 2, 2, 0, 0], [1, 2, 16, 16, 1], [0, 1, 11, 27, 11], [0, 0, 2, 7, 14]]
# <class 'list'>
# p value is 1.0856814131868727e-07
# Dependent (reject H0)

# %%
# Defining the table
data_crosstab = pd.crosstab(Starbucks_Data['loyal'], Starbucks_Data['serviceRate'],margins = False)
print(data_crosstab)

data = data_crosstab.values.tolist()
print(data)
#data = [[207, 282, 241], [234, 242, 232]]
print(type(data))
stat, p, dof, expected = chi2_contingency(data)

# Interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# serviceRate  2   3   4   5
# loyal
# 0            2  30  36  22
# 1            2   6  14   1
# [[2, 30, 36, 22], [2, 6, 14, 1]]
# <class 'list'>
# p value is 0.0479404615810394
# Dependent (reject H0)

# %%
# Defining the table
data_crosstab = pd.crosstab(Starbucks_Data['serviceRate'], Starbucks_Data['priceRate'],margins = False)
print(data_crosstab)

data = data_crosstab.values.tolist()
print(data)
print(type(data))
stat, p, dof, expected = chi2_contingency(data)

# Interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# priceRate    1   2   3   4  5
# serviceRate
# 2            1   1   1   1  0
# 3            7   7  17   4  1
# 4            4  13  18  14  1
# 5            0   4   8   4  7
# [[1, 1, 1, 1, 0], [7, 7, 17, 4, 1], [4, 13, 18, 14, 1], [0, 4, 8, 4, 7]]
# <class 'list'>
# p value is 0.0034669885361931036
# Dependent (reject H0)

# %% [markdown]
# # Analysis - 3 Using Decision Trees

# %%
# Importing libraries

import pandas as pd
import numpy as np
from pandas import DataFrame

from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
# Read starbbucks data

Starbucks_Data = pd.read_csv('Starbucks satisfactory survey encode cleaned.csv', header=0)
Starbucks_Data
# Out:
#       Id  gender  age  status  income  visitNo  method  timeSpend  location  \
# 0      1       1    1       0       0        3       0          1         0
# 1      2       1    1       0       0        3       2          0         1
# 2      3       0    1       2       0        2       0          1         2
# 3      4       1    1       0       0        3       2          0         2
# 4      5       0    1       0       0        2       2          1         1
# ..   ...     ...  ...     ...     ...      ...     ...        ...       ...
# 108  118       0    3       1       1        2       0          2         1
# 109  119       0    1       2       0        2       0          2         1
# 110  120       0    1       0       0        3       0          1         1
# 111  121       1    1       2       0        3       2          0         0
# 112  122       0    1       2       2        3       0          1         1
#
# ...

# %%
# Prepare the data data

X = Starbucks_Data.iloc[:,[5,8]]
y = Starbucks_Data['loyal']
print(X)
print(y)

# Fit the classifier with default hyper-parameters

clf = DecisionTreeClassifier(random_state=1234)
class_names = Starbucks_Data.columns[-1]

col = [5,8]
feature_names = Starbucks_Data.columns[col]
model = clf.fit(X, y)
# Out:
#      visitNo  location
# 0          3         0
# 1          3         1
# 2          2         2
# 3          3         2
# 4          2         1
# ..       ...       ...
# 108        2         1
# 109        2         1
# 110        3         1
# 111        3         0
# 112        3         1
#
# [113 rows x 2 columns]
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 108    0
# 109    0
# 110    1
# 111    0
# 112    1
# Name: loyal, Length: 113, dtype: int64

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=feature_names,  
                   class_names=class_names,
                   filled=True)

# %% [markdown]
# # Building Decision Tree Model

# %% [markdown]
# Since the features in our dataset are categorical variables, we opted Decision Tree for building our model as Linear Regression works only on continuous variables.

# %%
features = Starbucks_Data[['visitNo', 'location']]

# %%
labels = Starbucks_Data['loyal'].to_frame()

# %%
# Importing libraries

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Splitting the dataset for train and test

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = 0.20, stratify = labels, random_state = 123)

# %%
model = DecisionTreeClassifier()

# Training the model
model = model.fit(X_train, y_train)

# %%
# Predicting the test set values
y_pred = model.predict(X_test)

# %%
#Checking Accuracy of the model

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.782608695652174
